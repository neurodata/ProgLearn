# %% [markdown]
# # ProgLearn on spoken_digit

# %%
import os #read path
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import librosa #process audio
import librosa.display
import cv2
import time

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import train_test_split

# %%
from proglearn.progressive_learner import ProgressiveLearner
from proglearn.deciders import SimpleArgmaxAverage
from proglearn.transformers import (
    TreeClassificationTransformer,
    NeuralClassificationTransformer,
)
from proglearn.voters import TreeClassificationVoter, KNNClassificationVoter

# %%
file = os.listdir('D:/Python Exploration/free-spoken-digit-dataset/recordings')
AudioData=[] #audio data
X_spec = [] #STFT spectrum by librosa
X_spec_mini = [] #resize to 28*28
Y_number = [] #label of number
Y_speaker = [] #label of speaker

Label_speaker = ['g', 'j', 'l', 'n', 't', 'y'] #first letter of speaker's name

for i in file:
    x , sr = librosa.load('D:/Python Exploration/free-spoken-digit-dataset/recordings/'+i, sr = 8000) # path of the audio files
    X = librosa.stft(x,n_fft = 128) #short time fourier transform
    Xdb = librosa.amplitude_to_db(abs(X)) #Convert an amplitude spectrogram to dB-scaled spectrogram
    Xdb_28 = cv2.resize(Xdb, (28, 28))
    y_n = i[0] #number
    y_s = i[2] #first letter of speaker
    
    AudioData.append(x)
    X_spec.append(Xdb)
    X_spec_mini.append(Xdb_28)
    Y_number.append(y_n)
    Y_speaker.append(y_s)

# %%
# play the audio (NO.3000 audio, number 9)
import IPython.display as ipd

num = 2222
print('This is a number',Y_number[num],'spoken by speaker',Y_speaker[num],'\nLength:',AudioData[num].shape[0],'points')
ipd.Audio(AudioData[num], rate=sr)
# Out:
# This is a number 7 spoken by speaker l
# Length: 10399 points
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# check the effects of .resize()
num = 250 #choose from 0 to 2999
fig, axs = plt.subplots(nrows=1, ncols=2,figsize=(10, 8),gridspec_kw={'width_ratios': [3, 1]})
axs[0].imshow(X_spec[num], cmap='hot', interpolation='nearest')
axs[0].set_title('Number '+Y_number[num]+' spoken by '+Y_speaker[num])

axs[1].imshow(X_spec_mini[num], cmap='hot', interpolation= 'nearest')
axs[1].set_title('28x28')
# Out:
# Text(0.5, 1.0, '28x28')

# %% [markdown]
# # use the 28x28 for further analysis

# %%
# Description
n_audio = 3000
n_speaker = 6
n_per_class = 10
n_per_class_per_speaker = 50

# Flattening
X_all = np.array(X_spec_mini).reshape(n_audio,-1) #(3000, 784)
Y_all = np.array(Y_number).astype(int)#.reshape(n_audio,-1) #(3000, 1) ## it seems that the shape should be (3000,) rather than (3000,1)
Y_all_speaker = np.array(Y_speaker) #(3000,)string

# %%
Y_all_speaker
# Out:
# array(['g', 'g', 'g', ..., 'y', 'y', 'y'], dtype='<U1')

# %%
#
number = 9 #choose a number
fig, axes = plt.subplots(nrows=6, ncols=8, sharex=True, sharey=True, figsize=(12, 9))

for j,speaker in enumerate(Label_speaker):
    opt = np.where((Y_all_speaker == speaker)&(Y_all == number))[0]
    ch = np.random.choice(opt,8,replace=False) #randomly choose 8 different samples for plotting
    print(speaker)
    print(ch)
    for i in range(8):
        axes[j,i].imshow(X_spec_mini[ch[i]], cmap='hot', interpolation='nearest')
        axes[j,i].axis('off')
        if i == 0: axes[j,i].text(-9, 12, 'speaker '+speaker, size=14, va='center', rotation='vertical')
        else: continue
                
plt.subplots_adjust(top=0.92, bottom=0.08, left=0.10, right=0.95, hspace=0.05,
                    wspace=0.05)
plt.suptitle("Short-Time Fourier Transform Spectrogram of Number "+str(number)+" by Six Speakers", fontsize=18)
# Out:
# g
# [2745 2738 2710 2708 2701 2743 2749 2702]
# j
# [2751 2766 2754 2761 2756 2778 2784 2777]
# l
# [2807 2803 2804 2838 2822 2842 2816 2800]
# n
# [2881 2863 2854 2861 2873 2868 2876 2886]
# t
# [2939 2941 2930 2905 2946 2944 2914 2928]
# y
# [2973 2954 2977 2965 2958 2988 2983 2967]
# Text(0.5, 0.98, 'Short-Time Fourier Transform Spectrogram of Number 9 by Six Speakers')

# %% [markdown]
# ### Cross-validation
# The dataset is small. So I use cross-validation and average the result, in order to make it more reliable. Also, I should run it for enough iterations.

# %%
df = pd.DataFrame()

acc = []
num_trees = []
time_train = []
time_inf = []

########################################################### initialize proglearn
default_transformer_class = TreeClassificationTransformer
default_transformer_kwargs = {"kwargs": {"max_depth": 30}}
default_voter_class = TreeClassificationVoter
default_voter_kwargs = {}
default_decider_class = SimpleArgmaxAverage

###########################################################
for i in range(2):
    for n_tree in range(10,31):
        accuracies = []
        train_times_across_tasks = []
        inference_times_across_tasks = []

        skf = StratifiedKFold(n_splits = 10)
        for train_idx, test_idx in skf.split(X_all, Y_all):

            X_train , X_test = X_all[train_idx] , X_all[test_idx]
            Y_train , Y_test = Y_all[train_idx] , Y_all[test_idx]

            progressive_learner = ProgressiveLearner(
                default_transformer_class=default_transformer_class,
                default_transformer_kwargs=default_transformer_kwargs,
                default_voter_class=default_voter_class,
                default_voter_kwargs=default_voter_kwargs,
                default_decider_class=default_decider_class,
            )
            train_start_time = time.time()
            progressive_learner.add_task(
                X=X_train,
                y=Y_train,
                task_id=0,
                num_transformers=n_tree,
                transformer_voter_decider_split=[0.67, 0.33, 0],
                decider_kwargs={"classes": np.unique(Y_train)},
            )

            train_end_time = time.time()

            inference_start_time = time.time()
            task_0_predictions = progressive_learner.predict(X_test, task_id=0)
            inference_end_time = time.time()
            accuracies.append(np.mean(task_0_predictions == Y_test))
            train_times_across_tasks.append(train_end_time - train_start_time)
            inference_times_across_tasks.append(inference_end_time - inference_start_time)
            print('iter: ',i,'\nn_tree: ',n_tree,', cross-validation.','Current accuracies:',accuracies)
        num_trees.append(n_tree)
        acc.append(np.mean(accuracies))
        time_train.append(np.mean(train_times_across_tasks))
        time_inf.append(np.mean(inference_times_across_tasks))
        print('When n_tree is ',n_tree,', the accuracy is ',np.mean(accuracies))
# Out:
# iter:  0
# n_tree:  10 , cross-validation. Current accuracies: [0.72]
# iter:  0
# n_tree:  10 , cross-validation. Current accuracies: [0.72, 0.8566666666666667]
# iter:  0
# n_tree:  10 , cross-validation. Current accuracies: [0.72, 0.8566666666666667, 0.7633333333333333]
# iter:  0
# n_tree:  10 , cross-validation. Current accuracies: [0.72, 0.8566666666666667, 0.7633333333333333, 0.7233333333333334]
# iter:  0
# n_tree:  10 , cross-validation. Current accuracies: [0.72, 0.8566666666666667, 0.7633333333333333, 0.7233333333333334, 0.6266666666666667]
# iter:  0
# n_tree:  10 , cross-validation. Current accuracies: [0.72, 0.8566666666666667, 0.7633333333333333, 0.7233333333333334, 0.6266666666666667, 0.7533333333333333]
# iter:  0
# n_tree:  10 , cross-validation. Current accuracies: [0.72, 0.8566666666666667, 0.7633333333333333, 0.7233333333333334, 0.6266666666666667, 0.7533333333333333, 0.83]
# iter:  0
# n_tree:  10 , cross-validation. Current accuracies: [0.72, 0.8566666666666667, 0.7633333333333333, 0.7233333333333334, 0.6266666666666667, 0.7533333333333333, 0.83, 0.7166666666666667]
# iter:  0
# n_tree:  10 , cross-validation. Current accuracies: [0.72, 0.8566666666666667, 0.7633333333333333, 0.7233333333333334, 0.6266666666666667, 0.7533333333333333, 0.83, 0.7166666666666667, 0.7766666666666666]
# iter:  0
# n_tree:  10 , cross-validation. Current accuracies: [0.72, 0.8566666666666667, 0.7633333333333333, 0.7233333333333334, 0.6266666666666667, 0.7533333333333333, 0.83, 0.7166666666666667, 0.7766666666666666, 0.7066666666666667]
# When n_tree is  10 , the accuracy is  0.7473333333333334
# iter:  0
# n_tree:  11 , cross-validation. Current accuracies: [0.76]
# iter:  0
# n_tree:  11 , cross-validation. Current accuracies: [0.76, 0.8666666666666667]
# iter:  0
# n_tree:  11 , cross-validation. Current accuracies: [0.76, 0.8666666666666667, 0.8033333333333333]
# iter:  0
# n_tree:  11 , cross-validation. Current accuracies: [0.76, 0.8666666666666667, 0.8033333333333333, 0.73]
# iter:  0
# n_tree:  11 , cross-validation. Current accuracies: [0.76, 0.8666666666666667, 0.8033333333333333, 0.73, 0.57]
# iter:  0
# n_tree:  11 , cross-validation. Current accuracies: [0.76, 0.8666666666666667, 0.8033333333333333, 0.73, 0.57, 0.6933333333333334]
# iter:  0
# n_tree:  11 , cross-validation. Current accuracies: [0.76, 0.8666666666666667, 0.8033333333333333, 0.73, 0.57, 0.6933333333333334, 0.8166666666666667]
# iter:  0
# n_tree:  11 , cross-validation. Current accuracies: [0.76, 0.8666666666666667, 0.8033333333333333, 0.73, 0.57, 0.6933333333333334, 0.8166666666666667, 0.7]
# iter:  0
# n_tree:  11 , cross-validation. Current accuracies: [0.76, 0.8666666666666667, 0.8033333333333333, 0.73, 0.57, 0.6933333333333334, 0.8166666666666667, 0.7, 0.8033333333333333]
# iter:  0
# n_tree:  11 , cross-validation. Current accuracies: [0.76, 0.8666666666666667, 0.8033333333333333, 0.73, 0.57, 0.6933333333333334, 0.8166666666666667, 0.7, 0.8033333333333333, 0.7133333333333334]
# When n_tree is  11 , the accuracy is  0.7456666666666667
# iter:  0
# n_tree:  12 , cross-validation. Current accuracies: [0.75]
# iter:  0
# n_tree:  12 , cross-validation. Current accuracies: [0.75, 0.8333333333333334]
# iter:  0
# n_tree:  12 , cross-validation. Current accuracies: [0.75, 0.8333333333333334, 0.7833333333333333]
# iter:  0
# n_tree:  12 , cross-validation. Current accuracies: [0.75, 0.8333333333333334, 0.7833333333333333, 0.71]
# iter:  0
# n_tree:  12 , cross-validation. Current accuracies: [0.75, 0.8333333333333334, 0.7833333333333333, 0.71, 0.56]
# iter:  0
# n_tree:  12 , cross-validation. Current accuracies: [0.75, 0.8333333333333334, 0.7833333333333333, 0.71, 0.56, 0.7533333333333333]
# iter:  0
# n_tree:  12 , cross-validation. Current accuracies: [0.75, 0.8333333333333334, 0.7833333333333333, 0.71, 0.56, 0.7533333333333333, 0.7733333333333333]
# iter:  0
# n_tree:  12 , cross-validation. Current accuracies: [0.75, 0.8333333333333334, 0.7833333333333333, 0.71, 0.56, 0.7533333333333333, 0.7733333333333333, 0.7633333333333333]
# iter:  0
# n_tree:  12 , cross-validation. Current accuracies: [0.75, 0.8333333333333334, 0.7833333333333333, 0.71, 0.56, 0.7533333333333333, 0.7733333333333333, 0.7633333333333333, 0.81]
# iter:  0
# n_tree:  12 , cross-validation. Current accuracies: [0.75, 0.8333333333333334, 0.7833333333333333, 0.71, 0.56, 0.7533333333333333, 0.7733333333333333, 0.7633333333333333, 0.81, 0.7033333333333334]
# When n_tree is  12 , the accuracy is  0.744
# iter:  0
# n_tree:  13 , cross-validation. Current accuracies: [0.73]
# iter:  0
# n_tree:  13 , cross-validation. Current accuracies: [0.73, 0.8233333333333334]
# iter:  0
# n_tree:  13 , cross-validation. Current accuracies: [0.73, 0.8233333333333334, 0.83]
# iter:  0
# n_tree:  13 , cross-validation. Current accuracies: [0.73, 0.8233333333333334, 0.83, 0.7566666666666667]
# iter:  0
# n_tree:  13 , cross-validation. Current accuracies: [0.73, 0.8233333333333334, 0.83, 0.7566666666666667, 0.5966666666666667]
# iter:  0
# n_tree:  13 , cross-validation. Current accuracies: [0.73, 0.8233333333333334, 0.83, 0.7566666666666667, 0.5966666666666667, 0.7133333333333334]
# iter:  0
# n_tree:  13 , cross-validation. Current accuracies: [0.73, 0.8233333333333334, 0.83, 0.7566666666666667, 0.5966666666666667, 0.7133333333333334, 0.8033333333333333]
# iter:  0
# n_tree:  13 , cross-validation. Current accuracies: [0.73, 0.8233333333333334, 0.83, 0.7566666666666667, 0.5966666666666667, 0.7133333333333334, 0.8033333333333333, 0.7466666666666667]
# iter:  0
# n_tree:  13 , cross-validation. Current accuracies: [0.73, 0.8233333333333334, 0.83, 0.7566666666666667, 0.5966666666666667, 0.7133333333333334, 0.8033333333333333, 0.7466666666666667, 0.78]
# iter:  0
# n_tree:  13 , cross-validation. Current accuracies: [0.73, 0.8233333333333334, 0.83, 0.7566666666666667, 0.5966666666666667, 0.7133333333333334, 0.8033333333333333, 0.7466666666666667, 0.78, 0.7266666666666667]
# When n_tree is  13 , the accuracy is  0.7506666666666667
# iter:  0
# n_tree:  14 , cross-validation. Current accuracies: [0.73]
# iter:  0
# n_tree:  14 , cross-validation. Current accuracies: [0.73, 0.8266666666666667]
# iter:  0
# n_tree:  14 , cross-validation. Current accuracies: [0.73, 0.8266666666666667, 0.8266666666666667]
# iter:  0
# n_tree:  14 , cross-validation. Current accuracies: [0.73, 0.8266666666666667, 0.8266666666666667, 0.7733333333333333]
# iter:  0
# n_tree:  14 , cross-validation. Current accuracies: [0.73, 0.8266666666666667, 0.8266666666666667, 0.7733333333333333, 0.6633333333333333]
# iter:  0
# n_tree:  14 , cross-validation. Current accuracies: [0.73, 0.8266666666666667, 0.8266666666666667, 0.7733333333333333, 0.6633333333333333, 0.7233333333333334]
# iter:  0
# n_tree:  14 , cross-validation. Current accuracies: [0.73, 0.8266666666666667, 0.8266666666666667, 0.7733333333333333, 0.6633333333333333, 0.7233333333333334, 0.8]
# iter:  0
# n_tree:  14 , cross-validation. Current accuracies: [0.73, 0.8266666666666667, 0.8266666666666667, 0.7733333333333333, 0.6633333333333333, 0.7233333333333334, 0.8, 0.72]
# iter:  0
# n_tree:  14 , cross-validation. Current accuracies: [0.73, 0.8266666666666667, 0.8266666666666667, 0.7733333333333333, 0.6633333333333333, 0.7233333333333334, 0.8, 0.72, 0.8133333333333334]
# iter:  0
# n_tree:  14 , cross-validation. Current accuracies: [0.73, 0.8266666666666667, 0.8266666666666667, 0.7733333333333333, 0.6633333333333333, 0.7233333333333334, 0.8, 0.72, 0.8133333333333334, 0.7266666666666667]
# When n_tree is  14 , the accuracy is  0.7603333333333333
# iter:  0
# n_tree:  15 , cross-validation. Current accuracies: [0.7533333333333333]
# iter:  0
# n_tree:  15 , cross-validation. Current accuracies: [0.7533333333333333, 0.89]
# iter:  0
# n_tree:  15 , cross-validation. Current accuracies: [0.7533333333333333, 0.89, 0.8233333333333334]
# iter:  0
# n_tree:  15 , cross-validation. Current accuracies: [0.7533333333333333, 0.89, 0.8233333333333334, 0.7633333333333333]
# iter:  0
# n_tree:  15 , cross-validation. Current accuracies: [0.7533333333333333, 0.89, 0.8233333333333334, 0.7633333333333333, 0.62]
# iter:  0
# n_tree:  15 , cross-validation. Current accuracies: [0.7533333333333333, 0.89, 0.8233333333333334, 0.7633333333333333, 0.62, 0.72]
# iter:  0
# n_tree:  15 , cross-validation. Current accuracies: [0.7533333333333333, 0.89, 0.8233333333333334, 0.7633333333333333, 0.62, 0.72, 0.7866666666666666]
# iter:  0
# n_tree:  15 , cross-validation. Current accuracies: [0.7533333333333333, 0.89, 0.8233333333333334, 0.7633333333333333, 0.62, 0.72, 0.7866666666666666, 0.7566666666666667]
# iter:  0
# n_tree:  15 , cross-validation. Current accuracies: [0.7533333333333333, 0.89, 0.8233333333333334, 0.7633333333333333, 0.62, 0.72, 0.7866666666666666, 0.7566666666666667, 0.84]
# iter:  0
# n_tree:  15 , cross-validation. Current accuracies: [0.7533333333333333, 0.89, 0.8233333333333334, 0.7633333333333333, 0.62, 0.72, 0.7866666666666666, 0.7566666666666667, 0.84, 0.72]
# When n_tree is  15 , the accuracy is  0.7673333333333333
# iter:  0
# n_tree:  16 , cross-validation. Current accuracies: [0.7133333333333334]
# iter:  0
# n_tree:  16 , cross-validation. Current accuracies: [0.7133333333333334, 0.8366666666666667]
# iter:  0
# n_tree:  16 , cross-validation. Current accuracies: [0.7133333333333334, 0.8366666666666667, 0.82]
# iter:  0
# n_tree:  16 , cross-validation. Current accuracies: [0.7133333333333334, 0.8366666666666667, 0.82, 0.8366666666666667]
# iter:  0
# n_tree:  16 , cross-validation. Current accuracies: [0.7133333333333334, 0.8366666666666667, 0.82, 0.8366666666666667, 0.5833333333333334]
# iter:  0
# n_tree:  16 , cross-validation. Current accuracies: [0.7133333333333334, 0.8366666666666667, 0.82, 0.8366666666666667, 0.5833333333333334, 0.7866666666666666]
# iter:  0
# n_tree:  16 , cross-validation. Current accuracies: [0.7133333333333334, 0.8366666666666667, 0.82, 0.8366666666666667, 0.5833333333333334, 0.7866666666666666, 0.81]
# iter:  0
# n_tree:  16 , cross-validation. Current accuracies: [0.7133333333333334, 0.8366666666666667, 0.82, 0.8366666666666667, 0.5833333333333334, 0.7866666666666666, 0.81, 0.75]
# iter:  0
# n_tree:  16 , cross-validation. Current accuracies: [0.7133333333333334, 0.8366666666666667, 0.82, 0.8366666666666667, 0.5833333333333334, 0.7866666666666666, 0.81, 0.75, 0.8133333333333334]
# iter:  0
# n_tree:  16 , cross-validation. Current accuracies: [0.7133333333333334, 0.8366666666666667, 0.82, 0.8366666666666667, 0.5833333333333334, 0.7866666666666666, 0.81, 0.75, 0.8133333333333334, 0.7533333333333333]
# When n_tree is  16 , the accuracy is  0.7703333333333333
# iter:  0
# n_tree:  17 , cross-validation. Current accuracies: [0.76]
# iter:  0
# n_tree:  17 , cross-validation. Current accuracies: [0.76, 0.8433333333333334]
# iter:  0
# n_tree:  17 , cross-validation. Current accuracies: [0.76, 0.8433333333333334, 0.85]
# iter:  0
# n_tree:  17 , cross-validation. Current accuracies: [0.76, 0.8433333333333334, 0.85, 0.8266666666666667]
# iter:  0
# n_tree:  17 , cross-validation. Current accuracies: [0.76, 0.8433333333333334, 0.85, 0.8266666666666667, 0.6033333333333334]
# iter:  0
# n_tree:  17 , cross-validation. Current accuracies: [0.76, 0.8433333333333334, 0.85, 0.8266666666666667, 0.6033333333333334, 0.73]
# iter:  0
# n_tree:  17 , cross-validation. Current accuracies: [0.76, 0.8433333333333334, 0.85, 0.8266666666666667, 0.6033333333333334, 0.73, 0.7933333333333333]
# iter:  0
# n_tree:  17 , cross-validation. Current accuracies: [0.76, 0.8433333333333334, 0.85, 0.8266666666666667, 0.6033333333333334, 0.73, 0.7933333333333333, 0.8433333333333334]
# iter:  0
# n_tree:  17 , cross-validation. Current accuracies: [0.76, 0.8433333333333334, 0.85, 0.8266666666666667, 0.6033333333333334, 0.73, 0.7933333333333333, 0.8433333333333334, 0.85]
# iter:  0
# n_tree:  17 , cross-validation. Current accuracies: [0.76, 0.8433333333333334, 0.85, 0.8266666666666667, 0.6033333333333334, 0.73, 0.7933333333333333, 0.8433333333333334, 0.85, 0.7133333333333334]
# When n_tree is  17 , the accuracy is  0.7813333333333332
# iter:  0
# n_tree:  18 , cross-validation. Current accuracies: [0.76]
# iter:  0
# n_tree:  18 , cross-validation. Current accuracies: [0.76, 0.87]
# iter:  0
# n_tree:  18 , cross-validation. Current accuracies: [0.76, 0.87, 0.8233333333333334]
# iter:  0
# n_tree:  18 , cross-validation. Current accuracies: [0.76, 0.87, 0.8233333333333334, 0.77]
# iter:  0
# n_tree:  18 , cross-validation. Current accuracies: [0.76, 0.87, 0.8233333333333334, 0.77, 0.66]
# iter:  0
# n_tree:  18 , cross-validation. Current accuracies: [0.76, 0.87, 0.8233333333333334, 0.77, 0.66, 0.7433333333333333]
# iter:  0
# n_tree:  18 , cross-validation. Current accuracies: [0.76, 0.87, 0.8233333333333334, 0.77, 0.66, 0.7433333333333333, 0.8033333333333333]
# iter:  0
# n_tree:  18 , cross-validation. Current accuracies: [0.76, 0.87, 0.8233333333333334, 0.77, 0.66, 0.7433333333333333, 0.8033333333333333, 0.8433333333333334]
# iter:  0
# n_tree:  18 , cross-validation. Current accuracies: [0.76, 0.87, 0.8233333333333334, 0.77, 0.66, 0.7433333333333333, 0.8033333333333333, 0.8433333333333334, 0.8266666666666667]
# iter:  0
# n_tree:  18 , cross-validation. Current accuracies: [0.76, 0.87, 0.8233333333333334, 0.77, 0.66, 0.7433333333333333, 0.8033333333333333, 0.8433333333333334, 0.8266666666666667, 0.74]
# When n_tree is  18 , the accuracy is  0.784
# iter:  0
# n_tree:  19 , cross-validation. Current accuracies: [0.7533333333333333]
# iter:  0
# n_tree:  19 , cross-validation. Current accuracies: [0.7533333333333333, 0.8466666666666667]
# iter:  0
# n_tree:  19 , cross-validation. Current accuracies: [0.7533333333333333, 0.8466666666666667, 0.8133333333333334]
# iter:  0
# n_tree:  19 , cross-validation. Current accuracies: [0.7533333333333333, 0.8466666666666667, 0.8133333333333334, 0.7833333333333333]
# iter:  0
# n_tree:  19 , cross-validation. Current accuracies: [0.7533333333333333, 0.8466666666666667, 0.8133333333333334, 0.7833333333333333, 0.6933333333333334]
# iter:  0
# n_tree:  19 , cross-validation. Current accuracies: [0.7533333333333333, 0.8466666666666667, 0.8133333333333334, 0.7833333333333333, 0.6933333333333334, 0.74]
# iter:  0
# n_tree:  19 , cross-validation. Current accuracies: [0.7533333333333333, 0.8466666666666667, 0.8133333333333334, 0.7833333333333333, 0.6933333333333334, 0.74, 0.8633333333333333]
# iter:  0
# n_tree:  19 , cross-validation. Current accuracies: [0.7533333333333333, 0.8466666666666667, 0.8133333333333334, 0.7833333333333333, 0.6933333333333334, 0.74, 0.8633333333333333, 0.8033333333333333]
# iter:  0
# n_tree:  19 , cross-validation. Current accuracies: [0.7533333333333333, 0.8466666666666667, 0.8133333333333334, 0.7833333333333333, 0.6933333333333334, 0.74, 0.8633333333333333, 0.8033333333333333, 0.7866666666666666]
# iter:  0
# n_tree:  19 , cross-validation. Current accuracies: [0.7533333333333333, 0.8466666666666667, 0.8133333333333334, 0.7833333333333333, 0.6933333333333334, 0.74, 0.8633333333333333, 0.8033333333333333, 0.7866666666666666, 0.7633333333333333]
# When n_tree is  19 , the accuracy is  0.7846666666666667
# iter:  0
# n_tree:  20 , cross-validation. Current accuracies: [0.7766666666666666]
# iter:  0
# n_tree:  20 , cross-validation. Current accuracies: [0.7766666666666666, 0.8233333333333334]
# iter:  0
# n_tree:  20 , cross-validation. Current accuracies: [0.7766666666666666, 0.8233333333333334, 0.8666666666666667]
# iter:  0
# n_tree:  20 , cross-validation. Current accuracies: [0.7766666666666666, 0.8233333333333334, 0.8666666666666667, 0.7933333333333333]
# iter:  0
# n_tree:  20 , cross-validation. Current accuracies: [0.7766666666666666, 0.8233333333333334, 0.8666666666666667, 0.7933333333333333, 0.66]
# iter:  0
# n_tree:  20 , cross-validation. Current accuracies: [0.7766666666666666, 0.8233333333333334, 0.8666666666666667, 0.7933333333333333, 0.66, 0.7733333333333333]
# iter:  0
# n_tree:  20 , cross-validation. Current accuracies: [0.7766666666666666, 0.8233333333333334, 0.8666666666666667, 0.7933333333333333, 0.66, 0.7733333333333333, 0.8566666666666667]
# iter:  0
# n_tree:  20 , cross-validation. Current accuracies: [0.7766666666666666, 0.8233333333333334, 0.8666666666666667, 0.7933333333333333, 0.66, 0.7733333333333333, 0.8566666666666667, 0.8333333333333334]
# iter:  0
# n_tree:  20 , cross-validation. Current accuracies: [0.7766666666666666, 0.8233333333333334, 0.8666666666666667, 0.7933333333333333, 0.66, 0.7733333333333333, 0.8566666666666667, 0.8333333333333334, 0.8333333333333334]
# iter:  0
# n_tree:  20 , cross-validation. Current accuracies: [0.7766666666666666, 0.8233333333333334, 0.8666666666666667, 0.7933333333333333, 0.66, 0.7733333333333333, 0.8566666666666667, 0.8333333333333334, 0.8333333333333334, 0.7233333333333334]
# When n_tree is  20 , the accuracy is  0.7939999999999999
# iter:  0
# n_tree:  21 , cross-validation. Current accuracies: [0.7866666666666666]
# iter:  0
# n_tree:  21 , cross-validation. Current accuracies: [0.7866666666666666, 0.8533333333333334]
# iter:  0
# n_tree:  21 , cross-validation. Current accuracies: [0.7866666666666666, 0.8533333333333334, 0.8733333333333333]
# iter:  0
# n_tree:  21 , cross-validation. Current accuracies: [0.7866666666666666, 0.8533333333333334, 0.8733333333333333, 0.8166666666666667]
# iter:  0
# n_tree:  21 , cross-validation. Current accuracies: [0.7866666666666666, 0.8533333333333334, 0.8733333333333333, 0.8166666666666667, 0.6033333333333334]
# iter:  0
# n_tree:  21 , cross-validation. Current accuracies: [0.7866666666666666, 0.8533333333333334, 0.8733333333333333, 0.8166666666666667, 0.6033333333333334, 0.76]
# iter:  0
# n_tree:  21 , cross-validation. Current accuracies: [0.7866666666666666, 0.8533333333333334, 0.8733333333333333, 0.8166666666666667, 0.6033333333333334, 0.76, 0.8166666666666667]
# iter:  0
# n_tree:  21 , cross-validation. Current accuracies: [0.7866666666666666, 0.8533333333333334, 0.8733333333333333, 0.8166666666666667, 0.6033333333333334, 0.76, 0.8166666666666667, 0.8166666666666667]
# iter:  0
# n_tree:  21 , cross-validation. Current accuracies: [0.7866666666666666, 0.8533333333333334, 0.8733333333333333, 0.8166666666666667, 0.6033333333333334, 0.76, 0.8166666666666667, 0.8166666666666667, 0.7833333333333333]
# iter:  0
# n_tree:  21 , cross-validation. Current accuracies: [0.7866666666666666, 0.8533333333333334, 0.8733333333333333, 0.8166666666666667, 0.6033333333333334, 0.76, 0.8166666666666667, 0.8166666666666667, 0.7833333333333333, 0.78]
# When n_tree is  21 , the accuracy is  0.7889999999999999
# iter:  0
# n_tree:  22 , cross-validation. Current accuracies: [0.71]
# iter:  0
# n_tree:  22 , cross-validation. Current accuracies: [0.71, 0.87]
# iter:  0
# n_tree:  22 , cross-validation. Current accuracies: [0.71, 0.87, 0.8466666666666667]
# iter:  0
# n_tree:  22 , cross-validation. Current accuracies: [0.71, 0.87, 0.8466666666666667, 0.8033333333333333]
# iter:  0
# n_tree:  22 , cross-validation. Current accuracies: [0.71, 0.87, 0.8466666666666667, 0.8033333333333333, 0.6033333333333334]
# iter:  0
# n_tree:  22 , cross-validation. Current accuracies: [0.71, 0.87, 0.8466666666666667, 0.8033333333333333, 0.6033333333333334, 0.7933333333333333]
# iter:  0
# n_tree:  22 , cross-validation. Current accuracies: [0.71, 0.87, 0.8466666666666667, 0.8033333333333333, 0.6033333333333334, 0.7933333333333333, 0.8033333333333333]
# iter:  0
# n_tree:  22 , cross-validation. Current accuracies: [0.71, 0.87, 0.8466666666666667, 0.8033333333333333, 0.6033333333333334, 0.7933333333333333, 0.8033333333333333, 0.8466666666666667]
# iter:  0
# n_tree:  22 , cross-validation. Current accuracies: [0.71, 0.87, 0.8466666666666667, 0.8033333333333333, 0.6033333333333334, 0.7933333333333333, 0.8033333333333333, 0.8466666666666667, 0.8166666666666667]
# iter:  0
# n_tree:  22 , cross-validation. Current accuracies: [0.71, 0.87, 0.8466666666666667, 0.8033333333333333, 0.6033333333333334, 0.7933333333333333, 0.8033333333333333, 0.8466666666666667, 0.8166666666666667, 0.7366666666666667]
# When n_tree is  22 , the accuracy is  0.783
# iter:  0
# n_tree:  23 , cross-validation. Current accuracies: [0.7966666666666666]
# iter:  0
# n_tree:  23 , cross-validation. Current accuracies: [0.7966666666666666, 0.8433333333333334]
# iter:  0
# n_tree:  23 , cross-validation. Current accuracies: [0.7966666666666666, 0.8433333333333334, 0.8433333333333334]
# iter:  0
# n_tree:  23 , cross-validation. Current accuracies: [0.7966666666666666, 0.8433333333333334, 0.8433333333333334, 0.7833333333333333]
# iter:  0
# n_tree:  23 , cross-validation. Current accuracies: [0.7966666666666666, 0.8433333333333334, 0.8433333333333334, 0.7833333333333333, 0.66]
# iter:  0
# n_tree:  23 , cross-validation. Current accuracies: [0.7966666666666666, 0.8433333333333334, 0.8433333333333334, 0.7833333333333333, 0.66, 0.8066666666666666]
# iter:  0
# n_tree:  23 , cross-validation. Current accuracies: [0.7966666666666666, 0.8433333333333334, 0.8433333333333334, 0.7833333333333333, 0.66, 0.8066666666666666, 0.79]
# iter:  0
# n_tree:  23 , cross-validation. Current accuracies: [0.7966666666666666, 0.8433333333333334, 0.8433333333333334, 0.7833333333333333, 0.66, 0.8066666666666666, 0.79, 0.7833333333333333]
# iter:  0
# n_tree:  23 , cross-validation. Current accuracies: [0.7966666666666666, 0.8433333333333334, 0.8433333333333334, 0.7833333333333333, 0.66, 0.8066666666666666, 0.79, 0.7833333333333333, 0.8466666666666667]
# iter:  0
# n_tree:  23 , cross-validation. Current accuracies: [0.7966666666666666, 0.8433333333333334, 0.8433333333333334, 0.7833333333333333, 0.66, 0.8066666666666666, 0.79, 0.7833333333333333, 0.8466666666666667, 0.75]
# When n_tree is  23 , the accuracy is  0.7903333333333333
# iter:  0
# n_tree:  24 , cross-validation. Current accuracies: [0.73]
# iter:  0
# n_tree:  24 , cross-validation. Current accuracies: [0.73, 0.84]
# iter:  0
# n_tree:  24 , cross-validation. Current accuracies: [0.73, 0.84, 0.8333333333333334]
# iter:  0
# n_tree:  24 , cross-validation. Current accuracies: [0.73, 0.84, 0.8333333333333334, 0.78]
# iter:  0
# n_tree:  24 , cross-validation. Current accuracies: [0.73, 0.84, 0.8333333333333334, 0.78, 0.66]
# iter:  0
# n_tree:  24 , cross-validation. Current accuracies: [0.73, 0.84, 0.8333333333333334, 0.78, 0.66, 0.7566666666666667]
# iter:  0
# n_tree:  24 , cross-validation. Current accuracies: [0.73, 0.84, 0.8333333333333334, 0.78, 0.66, 0.7566666666666667, 0.8333333333333334]
# iter:  0
# n_tree:  24 , cross-validation. Current accuracies: [0.73, 0.84, 0.8333333333333334, 0.78, 0.66, 0.7566666666666667, 0.8333333333333334, 0.8266666666666667]
# iter:  0
# n_tree:  24 , cross-validation. Current accuracies: [0.73, 0.84, 0.8333333333333334, 0.78, 0.66, 0.7566666666666667, 0.8333333333333334, 0.8266666666666667, 0.8733333333333333]
# iter:  0
# n_tree:  24 , cross-validation. Current accuracies: [0.73, 0.84, 0.8333333333333334, 0.78, 0.66, 0.7566666666666667, 0.8333333333333334, 0.8266666666666667, 0.8733333333333333, 0.73]
# When n_tree is  24 , the accuracy is  0.7863333333333333
# iter:  0
# n_tree:  25 , cross-validation. Current accuracies: [0.73]
# iter:  0
# n_tree:  25 , cross-validation. Current accuracies: [0.73, 0.8866666666666667]
# iter:  0
# n_tree:  25 , cross-validation. Current accuracies: [0.73, 0.8866666666666667, 0.7733333333333333]
# iter:  0
# n_tree:  25 , cross-validation. Current accuracies: [0.73, 0.8866666666666667, 0.7733333333333333, 0.8]
# iter:  0
# n_tree:  25 , cross-validation. Current accuracies: [0.73, 0.8866666666666667, 0.7733333333333333, 0.8, 0.6966666666666667]
# iter:  0
# n_tree:  25 , cross-validation. Current accuracies: [0.73, 0.8866666666666667, 0.7733333333333333, 0.8, 0.6966666666666667, 0.77]
# iter:  0
# n_tree:  25 , cross-validation. Current accuracies: [0.73, 0.8866666666666667, 0.7733333333333333, 0.8, 0.6966666666666667, 0.77, 0.7966666666666666]
# iter:  0
# n_tree:  25 , cross-validation. Current accuracies: [0.73, 0.8866666666666667, 0.7733333333333333, 0.8, 0.6966666666666667, 0.77, 0.7966666666666666, 0.83]
# iter:  0
# n_tree:  25 , cross-validation. Current accuracies: [0.73, 0.8866666666666667, 0.7733333333333333, 0.8, 0.6966666666666667, 0.77, 0.7966666666666666, 0.83, 0.8433333333333334]
# iter:  0
# n_tree:  25 , cross-validation. Current accuracies: [0.73, 0.8866666666666667, 0.7733333333333333, 0.8, 0.6966666666666667, 0.77, 0.7966666666666666, 0.83, 0.8433333333333334, 0.7466666666666667]
# When n_tree is  25 , the accuracy is  0.7873333333333334
# iter:  0
# n_tree:  26 , cross-validation. Current accuracies: [0.74]
# iter:  0
# n_tree:  26 , cross-validation. Current accuracies: [0.74, 0.89]
# iter:  0
# n_tree:  26 , cross-validation. Current accuracies: [0.74, 0.89, 0.8066666666666666]
# iter:  0
# n_tree:  26 , cross-validation. Current accuracies: [0.74, 0.89, 0.8066666666666666, 0.7933333333333333]
# iter:  0
# n_tree:  26 , cross-validation. Current accuracies: [0.74, 0.89, 0.8066666666666666, 0.7933333333333333, 0.6733333333333333]
# iter:  0
# n_tree:  26 , cross-validation. Current accuracies: [0.74, 0.89, 0.8066666666666666, 0.7933333333333333, 0.6733333333333333, 0.7966666666666666]
# iter:  0
# n_tree:  26 , cross-validation. Current accuracies: [0.74, 0.89, 0.8066666666666666, 0.7933333333333333, 0.6733333333333333, 0.7966666666666666, 0.8133333333333334]
# iter:  0
# n_tree:  26 , cross-validation. Current accuracies: [0.74, 0.89, 0.8066666666666666, 0.7933333333333333, 0.6733333333333333, 0.7966666666666666, 0.8133333333333334, 0.78]
# iter:  0
# n_tree:  26 , cross-validation. Current accuracies: [0.74, 0.89, 0.8066666666666666, 0.7933333333333333, 0.6733333333333333, 0.7966666666666666, 0.8133333333333334, 0.78, 0.88]
# iter:  0
# n_tree:  26 , cross-validation. Current accuracies: [0.74, 0.89, 0.8066666666666666, 0.7933333333333333, 0.6733333333333333, 0.7966666666666666, 0.8133333333333334, 0.78, 0.88, 0.77]
# When n_tree is  26 , the accuracy is  0.7943333333333333
# iter:  0
# n_tree:  27 , cross-validation. Current accuracies: [0.8166666666666667]
# iter:  0
# n_tree:  27 , cross-validation. Current accuracies: [0.8166666666666667, 0.8433333333333334]
# iter:  0
# n_tree:  27 , cross-validation. Current accuracies: [0.8166666666666667, 0.8433333333333334, 0.8066666666666666]
# iter:  0
# n_tree:  27 , cross-validation. Current accuracies: [0.8166666666666667, 0.8433333333333334, 0.8066666666666666, 0.7633333333333333]
# iter:  0
# n_tree:  27 , cross-validation. Current accuracies: [0.8166666666666667, 0.8433333333333334, 0.8066666666666666, 0.7633333333333333, 0.6333333333333333]
# iter:  0
# n_tree:  27 , cross-validation. Current accuracies: [0.8166666666666667, 0.8433333333333334, 0.8066666666666666, 0.7633333333333333, 0.6333333333333333, 0.7766666666666666]
# iter:  0
# n_tree:  27 , cross-validation. Current accuracies: [0.8166666666666667, 0.8433333333333334, 0.8066666666666666, 0.7633333333333333, 0.6333333333333333, 0.7766666666666666, 0.8233333333333334]
# iter:  0
# n_tree:  27 , cross-validation. Current accuracies: [0.8166666666666667, 0.8433333333333334, 0.8066666666666666, 0.7633333333333333, 0.6333333333333333, 0.7766666666666666, 0.8233333333333334, 0.83]
# iter:  0
# n_tree:  27 , cross-validation. Current accuracies: [0.8166666666666667, 0.8433333333333334, 0.8066666666666666, 0.7633333333333333, 0.6333333333333333, 0.7766666666666666, 0.8233333333333334, 0.83, 0.84]
# iter:  0
# n_tree:  27 , cross-validation. Current accuracies: [0.8166666666666667, 0.8433333333333334, 0.8066666666666666, 0.7633333333333333, 0.6333333333333333, 0.7766666666666666, 0.8233333333333334, 0.83, 0.84, 0.83]
# When n_tree is  27 , the accuracy is  0.7963333333333333
# iter:  0
# n_tree:  28 , cross-validation. Current accuracies: [0.78]
# iter:  0
# n_tree:  28 , cross-validation. Current accuracies: [0.78, 0.8933333333333333]
# iter:  0
# n_tree:  28 , cross-validation. Current accuracies: [0.78, 0.8933333333333333, 0.84]
# iter:  0
# n_tree:  28 , cross-validation. Current accuracies: [0.78, 0.8933333333333333, 0.84, 0.8066666666666666]
# iter:  0
# n_tree:  28 , cross-validation. Current accuracies: [0.78, 0.8933333333333333, 0.84, 0.8066666666666666, 0.5933333333333334]
# iter:  0
# n_tree:  28 , cross-validation. Current accuracies: [0.78, 0.8933333333333333, 0.84, 0.8066666666666666, 0.5933333333333334, 0.7733333333333333]
# iter:  0
# n_tree:  28 , cross-validation. Current accuracies: [0.78, 0.8933333333333333, 0.84, 0.8066666666666666, 0.5933333333333334, 0.7733333333333333, 0.8133333333333334]
# iter:  0
# n_tree:  28 , cross-validation. Current accuracies: [0.78, 0.8933333333333333, 0.84, 0.8066666666666666, 0.5933333333333334, 0.7733333333333333, 0.8133333333333334, 0.8766666666666667]
# iter:  0
# n_tree:  28 , cross-validation. Current accuracies: [0.78, 0.8933333333333333, 0.84, 0.8066666666666666, 0.5933333333333334, 0.7733333333333333, 0.8133333333333334, 0.8766666666666667, 0.8166666666666667]
# iter:  0
# n_tree:  28 , cross-validation. Current accuracies: [0.78, 0.8933333333333333, 0.84, 0.8066666666666666, 0.5933333333333334, 0.7733333333333333, 0.8133333333333334, 0.8766666666666667, 0.8166666666666667, 0.76]
# When n_tree is  28 , the accuracy is  0.7953333333333333
# iter:  0
# n_tree:  29 , cross-validation. Current accuracies: [0.8266666666666667]
# iter:  0
# n_tree:  29 , cross-validation. Current accuracies: [0.8266666666666667, 0.8833333333333333]
# iter:  0
# n_tree:  29 , cross-validation. Current accuracies: [0.8266666666666667, 0.8833333333333333, 0.7966666666666666]
# iter:  0
# n_tree:  29 , cross-validation. Current accuracies: [0.8266666666666667, 0.8833333333333333, 0.7966666666666666, 0.81]
# iter:  0
# n_tree:  29 , cross-validation. Current accuracies: [0.8266666666666667, 0.8833333333333333, 0.7966666666666666, 0.81, 0.7033333333333334]
# iter:  0
# n_tree:  29 , cross-validation. Current accuracies: [0.8266666666666667, 0.8833333333333333, 0.7966666666666666, 0.81, 0.7033333333333334, 0.7666666666666667]
# iter:  0
# n_tree:  29 , cross-validation. Current accuracies: [0.8266666666666667, 0.8833333333333333, 0.7966666666666666, 0.81, 0.7033333333333334, 0.7666666666666667, 0.8433333333333334]
# iter:  0
# n_tree:  29 , cross-validation. Current accuracies: [0.8266666666666667, 0.8833333333333333, 0.7966666666666666, 0.81, 0.7033333333333334, 0.7666666666666667, 0.8433333333333334, 0.7733333333333333]
# iter:  0
# n_tree:  29 , cross-validation. Current accuracies: [0.8266666666666667, 0.8833333333333333, 0.7966666666666666, 0.81, 0.7033333333333334, 0.7666666666666667, 0.8433333333333334, 0.7733333333333333, 0.7866666666666666]
# iter:  0
# n_tree:  29 , cross-validation. Current accuracies: [0.8266666666666667, 0.8833333333333333, 0.7966666666666666, 0.81, 0.7033333333333334, 0.7666666666666667, 0.8433333333333334, 0.7733333333333333, 0.7866666666666666, 0.6866666666666666]
# When n_tree is  29 , the accuracy is  0.7876666666666666
# iter:  0
# n_tree:  30 , cross-validation. Current accuracies: [0.79]
# iter:  0
# n_tree:  30 , cross-validation. Current accuracies: [0.79, 0.8633333333333333]
# iter:  0
# n_tree:  30 , cross-validation. Current accuracies: [0.79, 0.8633333333333333, 0.8433333333333334]
# iter:  0
# n_tree:  30 , cross-validation. Current accuracies: [0.79, 0.8633333333333333, 0.8433333333333334, 0.7833333333333333]
# iter:  0
# n_tree:  30 , cross-validation. Current accuracies: [0.79, 0.8633333333333333, 0.8433333333333334, 0.7833333333333333, 0.6533333333333333]
# iter:  0
# n_tree:  30 , cross-validation. Current accuracies: [0.79, 0.8633333333333333, 0.8433333333333334, 0.7833333333333333, 0.6533333333333333, 0.8133333333333334]
# iter:  0
# n_tree:  30 , cross-validation. Current accuracies: [0.79, 0.8633333333333333, 0.8433333333333334, 0.7833333333333333, 0.6533333333333333, 0.8133333333333334, 0.8633333333333333]
# iter:  0
# n_tree:  30 , cross-validation. Current accuracies: [0.79, 0.8633333333333333, 0.8433333333333334, 0.7833333333333333, 0.6533333333333333, 0.8133333333333334, 0.8633333333333333, 0.8266666666666667]
# iter:  0
# n_tree:  30 , cross-validation. Current accuracies: [0.79, 0.8633333333333333, 0.8433333333333334, 0.7833333333333333, 0.6533333333333333, 0.8133333333333334, 0.8633333333333333, 0.8266666666666667, 0.8233333333333334]
# iter:  0
# n_tree:  30 , cross-validation. Current accuracies: [0.79, 0.8633333333333333, 0.8433333333333334, 0.7833333333333333, 0.6533333333333333, 0.8133333333333334, 0.8633333333333333, 0.8266666666666667, 0.8233333333333334, 0.77]
# When n_tree is  30 , the accuracy is  0.8030000000000002
# iter:  1
# n_tree:  10 , cross-validation. Current accuracies: [0.75]
# iter:  1
# n_tree:  10 , cross-validation. Current accuracies: [0.75, 0.84]
# iter:  1
# n_tree:  10 , cross-validation. Current accuracies: [0.75, 0.84, 0.7666666666666667]
# iter:  1
# n_tree:  10 , cross-validation. Current accuracies: [0.75, 0.84, 0.7666666666666667, 0.7233333333333334]
# iter:  1
# n_tree:  10 , cross-validation. Current accuracies: [0.75, 0.84, 0.7666666666666667, 0.7233333333333334, 0.6466666666666666]
# iter:  1
# n_tree:  10 , cross-validation. Current accuracies: [0.75, 0.84, 0.7666666666666667, 0.7233333333333334, 0.6466666666666666, 0.76]
# iter:  1
# n_tree:  10 , cross-validation. Current accuracies: [0.75, 0.84, 0.7666666666666667, 0.7233333333333334, 0.6466666666666666, 0.76, 0.79]
# iter:  1
# n_tree:  10 , cross-validation. Current accuracies: [0.75, 0.84, 0.7666666666666667, 0.7233333333333334, 0.6466666666666666, 0.76, 0.79, 0.6766666666666666]
# iter:  1
# n_tree:  10 , cross-validation. Current accuracies: [0.75, 0.84, 0.7666666666666667, 0.7233333333333334, 0.6466666666666666, 0.76, 0.79, 0.6766666666666666, 0.7933333333333333]
# iter:  1
# n_tree:  10 , cross-validation. Current accuracies: [0.75, 0.84, 0.7666666666666667, 0.7233333333333334, 0.6466666666666666, 0.76, 0.79, 0.6766666666666666, 0.7933333333333333, 0.6633333333333333]
# When n_tree is  10 , the accuracy is  0.7409999999999999
# iter:  1
# n_tree:  11 , cross-validation. Current accuracies: [0.7766666666666666]
# iter:  1
# n_tree:  11 , cross-validation. Current accuracies: [0.7766666666666666, 0.8233333333333334]
# iter:  1
# n_tree:  11 , cross-validation. Current accuracies: [0.7766666666666666, 0.8233333333333334, 0.7933333333333333]
# iter:  1
# n_tree:  11 , cross-validation. Current accuracies: [0.7766666666666666, 0.8233333333333334, 0.7933333333333333, 0.7566666666666667]
# iter:  1
# n_tree:  11 , cross-validation. Current accuracies: [0.7766666666666666, 0.8233333333333334, 0.7933333333333333, 0.7566666666666667, 0.59]
# iter:  1
# n_tree:  11 , cross-validation. Current accuracies: [0.7766666666666666, 0.8233333333333334, 0.7933333333333333, 0.7566666666666667, 0.59, 0.75]
# iter:  1
# n_tree:  11 , cross-validation. Current accuracies: [0.7766666666666666, 0.8233333333333334, 0.7933333333333333, 0.7566666666666667, 0.59, 0.75, 0.7733333333333333]
# iter:  1
# n_tree:  11 , cross-validation. Current accuracies: [0.7766666666666666, 0.8233333333333334, 0.7933333333333333, 0.7566666666666667, 0.59, 0.75, 0.7733333333333333, 0.7]
# iter:  1
# n_tree:  11 , cross-validation. Current accuracies: [0.7766666666666666, 0.8233333333333334, 0.7933333333333333, 0.7566666666666667, 0.59, 0.75, 0.7733333333333333, 0.7, 0.7733333333333333]
# iter:  1
# n_tree:  11 , cross-validation. Current accuracies: [0.7766666666666666, 0.8233333333333334, 0.7933333333333333, 0.7566666666666667, 0.59, 0.75, 0.7733333333333333, 0.7, 0.7733333333333333, 0.71]
# When n_tree is  11 , the accuracy is  0.7446666666666666
# iter:  1
# n_tree:  12 , cross-validation. Current accuracies: [0.75]
# iter:  1
# n_tree:  12 , cross-validation. Current accuracies: [0.75, 0.8533333333333334]
# iter:  1
# n_tree:  12 , cross-validation. Current accuracies: [0.75, 0.8533333333333334, 0.8333333333333334]
# iter:  1
# n_tree:  12 , cross-validation. Current accuracies: [0.75, 0.8533333333333334, 0.8333333333333334, 0.8166666666666667]
# iter:  1
# n_tree:  12 , cross-validation. Current accuracies: [0.75, 0.8533333333333334, 0.8333333333333334, 0.8166666666666667, 0.63]
# iter:  1
# n_tree:  12 , cross-validation. Current accuracies: [0.75, 0.8533333333333334, 0.8333333333333334, 0.8166666666666667, 0.63, 0.7366666666666667]
# iter:  1
# n_tree:  12 , cross-validation. Current accuracies: [0.75, 0.8533333333333334, 0.8333333333333334, 0.8166666666666667, 0.63, 0.7366666666666667, 0.8066666666666666]
# iter:  1
# n_tree:  12 , cross-validation. Current accuracies: [0.75, 0.8533333333333334, 0.8333333333333334, 0.8166666666666667, 0.63, 0.7366666666666667, 0.8066666666666666, 0.7733333333333333]
# iter:  1
# n_tree:  12 , cross-validation. Current accuracies: [0.75, 0.8533333333333334, 0.8333333333333334, 0.8166666666666667, 0.63, 0.7366666666666667, 0.8066666666666666, 0.7733333333333333, 0.7633333333333333]
# iter:  1
# n_tree:  12 , cross-validation. Current accuracies: [0.75, 0.8533333333333334, 0.8333333333333334, 0.8166666666666667, 0.63, 0.7366666666666667, 0.8066666666666666, 0.7733333333333333, 0.7633333333333333, 0.7233333333333334]
# When n_tree is  12 , the accuracy is  0.7686666666666667
# iter:  1
# n_tree:  13 , cross-validation. Current accuracies: [0.7]
# iter:  1
# n_tree:  13 , cross-validation. Current accuracies: [0.7, 0.8633333333333333]
# iter:  1
# n_tree:  13 , cross-validation. Current accuracies: [0.7, 0.8633333333333333, 0.7666666666666667]
# iter:  1
# n_tree:  13 , cross-validation. Current accuracies: [0.7, 0.8633333333333333, 0.7666666666666667, 0.79]
# iter:  1
# n_tree:  13 , cross-validation. Current accuracies: [0.7, 0.8633333333333333, 0.7666666666666667, 0.79, 0.5766666666666667]
# iter:  1
# n_tree:  13 , cross-validation. Current accuracies: [0.7, 0.8633333333333333, 0.7666666666666667, 0.79, 0.5766666666666667, 0.7833333333333333]
# iter:  1
# n_tree:  13 , cross-validation. Current accuracies: [0.7, 0.8633333333333333, 0.7666666666666667, 0.79, 0.5766666666666667, 0.7833333333333333, 0.7966666666666666]
# iter:  1
# n_tree:  13 , cross-validation. Current accuracies: [0.7, 0.8633333333333333, 0.7666666666666667, 0.79, 0.5766666666666667, 0.7833333333333333, 0.7966666666666666, 0.78]
# iter:  1
# n_tree:  13 , cross-validation. Current accuracies: [0.7, 0.8633333333333333, 0.7666666666666667, 0.79, 0.5766666666666667, 0.7833333333333333, 0.7966666666666666, 0.78, 0.8433333333333334]
# iter:  1
# n_tree:  13 , cross-validation. Current accuracies: [0.7, 0.8633333333333333, 0.7666666666666667, 0.79, 0.5766666666666667, 0.7833333333333333, 0.7966666666666666, 0.78, 0.8433333333333334, 0.7166666666666667]
# When n_tree is  13 , the accuracy is  0.7616666666666667
# iter:  1
# n_tree:  14 , cross-validation. Current accuracies: [0.73]
# iter:  1
# n_tree:  14 , cross-validation. Current accuracies: [0.73, 0.8566666666666667]
# iter:  1
# n_tree:  14 , cross-validation. Current accuracies: [0.73, 0.8566666666666667, 0.8033333333333333]
# iter:  1
# n_tree:  14 , cross-validation. Current accuracies: [0.73, 0.8566666666666667, 0.8033333333333333, 0.7933333333333333]
# iter:  1
# n_tree:  14 , cross-validation. Current accuracies: [0.73, 0.8566666666666667, 0.8033333333333333, 0.7933333333333333, 0.6133333333333333]
# iter:  1
# n_tree:  14 , cross-validation. Current accuracies: [0.73, 0.8566666666666667, 0.8033333333333333, 0.7933333333333333, 0.6133333333333333, 0.7633333333333333]
# iter:  1
# n_tree:  14 , cross-validation. Current accuracies: [0.73, 0.8566666666666667, 0.8033333333333333, 0.7933333333333333, 0.6133333333333333, 0.7633333333333333, 0.7566666666666667]
# iter:  1
# n_tree:  14 , cross-validation. Current accuracies: [0.73, 0.8566666666666667, 0.8033333333333333, 0.7933333333333333, 0.6133333333333333, 0.7633333333333333, 0.7566666666666667, 0.7366666666666667]
# iter:  1
# n_tree:  14 , cross-validation. Current accuracies: [0.73, 0.8566666666666667, 0.8033333333333333, 0.7933333333333333, 0.6133333333333333, 0.7633333333333333, 0.7566666666666667, 0.7366666666666667, 0.7566666666666667]
# iter:  1
# n_tree:  14 , cross-validation. Current accuracies: [0.73, 0.8566666666666667, 0.8033333333333333, 0.7933333333333333, 0.6133333333333333, 0.7633333333333333, 0.7566666666666667, 0.7366666666666667, 0.7566666666666667, 0.71]
# When n_tree is  14 , the accuracy is  0.752
# iter:  1
# n_tree:  15 , cross-validation. Current accuracies: [0.7466666666666667]
# iter:  1
# n_tree:  15 , cross-validation. Current accuracies: [0.7466666666666667, 0.8533333333333334]
# iter:  1
# n_tree:  15 , cross-validation. Current accuracies: [0.7466666666666667, 0.8533333333333334, 0.8133333333333334]
# iter:  1
# n_tree:  15 , cross-validation. Current accuracies: [0.7466666666666667, 0.8533333333333334, 0.8133333333333334, 0.7866666666666666]
# iter:  1
# n_tree:  15 , cross-validation. Current accuracies: [0.7466666666666667, 0.8533333333333334, 0.8133333333333334, 0.7866666666666666, 0.5833333333333334]
# iter:  1
# n_tree:  15 , cross-validation. Current accuracies: [0.7466666666666667, 0.8533333333333334, 0.8133333333333334, 0.7866666666666666, 0.5833333333333334, 0.7566666666666667]
# iter:  1
# n_tree:  15 , cross-validation. Current accuracies: [0.7466666666666667, 0.8533333333333334, 0.8133333333333334, 0.7866666666666666, 0.5833333333333334, 0.7566666666666667, 0.8366666666666667]
# iter:  1
# n_tree:  15 , cross-validation. Current accuracies: [0.7466666666666667, 0.8533333333333334, 0.8133333333333334, 0.7866666666666666, 0.5833333333333334, 0.7566666666666667, 0.8366666666666667, 0.78]
# iter:  1
# n_tree:  15 , cross-validation. Current accuracies: [0.7466666666666667, 0.8533333333333334, 0.8133333333333334, 0.7866666666666666, 0.5833333333333334, 0.7566666666666667, 0.8366666666666667, 0.78, 0.8433333333333334]
# iter:  1
# n_tree:  15 , cross-validation. Current accuracies: [0.7466666666666667, 0.8533333333333334, 0.8133333333333334, 0.7866666666666666, 0.5833333333333334, 0.7566666666666667, 0.8366666666666667, 0.78, 0.8433333333333334, 0.6933333333333334]
# When n_tree is  15 , the accuracy is  0.7693333333333334
# iter:  1
# n_tree:  16 , cross-validation. Current accuracies: [0.7033333333333334]
# iter:  1
# n_tree:  16 , cross-validation. Current accuracies: [0.7033333333333334, 0.8466666666666667]
# iter:  1
# n_tree:  16 , cross-validation. Current accuracies: [0.7033333333333334, 0.8466666666666667, 0.8033333333333333]
# iter:  1
# n_tree:  16 , cross-validation. Current accuracies: [0.7033333333333334, 0.8466666666666667, 0.8033333333333333, 0.7333333333333333]
# iter:  1
# n_tree:  16 , cross-validation. Current accuracies: [0.7033333333333334, 0.8466666666666667, 0.8033333333333333, 0.7333333333333333, 0.67]
# iter:  1
# n_tree:  16 , cross-validation. Current accuracies: [0.7033333333333334, 0.8466666666666667, 0.8033333333333333, 0.7333333333333333, 0.67, 0.7733333333333333]
# iter:  1
# n_tree:  16 , cross-validation. Current accuracies: [0.7033333333333334, 0.8466666666666667, 0.8033333333333333, 0.7333333333333333, 0.67, 0.7733333333333333, 0.83]
# iter:  1
# n_tree:  16 , cross-validation. Current accuracies: [0.7033333333333334, 0.8466666666666667, 0.8033333333333333, 0.7333333333333333, 0.67, 0.7733333333333333, 0.83, 0.8266666666666667]
# iter:  1
# n_tree:  16 , cross-validation. Current accuracies: [0.7033333333333334, 0.8466666666666667, 0.8033333333333333, 0.7333333333333333, 0.67, 0.7733333333333333, 0.83, 0.8266666666666667, 0.8166666666666667]
# iter:  1
# n_tree:  16 , cross-validation. Current accuracies: [0.7033333333333334, 0.8466666666666667, 0.8033333333333333, 0.7333333333333333, 0.67, 0.7733333333333333, 0.83, 0.8266666666666667, 0.8166666666666667, 0.6933333333333334]
# When n_tree is  16 , the accuracy is  0.7696666666666667
# iter:  1
# n_tree:  17 , cross-validation. Current accuracies: [0.77]
# iter:  1
# n_tree:  17 , cross-validation. Current accuracies: [0.77, 0.83]
# iter:  1
# n_tree:  17 , cross-validation. Current accuracies: [0.77, 0.83, 0.81]
# iter:  1
# n_tree:  17 , cross-validation. Current accuracies: [0.77, 0.83, 0.81, 0.74]
# iter:  1
# n_tree:  17 , cross-validation. Current accuracies: [0.77, 0.83, 0.81, 0.74, 0.65]
# iter:  1
# n_tree:  17 , cross-validation. Current accuracies: [0.77, 0.83, 0.81, 0.74, 0.65, 0.74]
# iter:  1
# n_tree:  17 , cross-validation. Current accuracies: [0.77, 0.83, 0.81, 0.74, 0.65, 0.74, 0.8166666666666667]
# iter:  1
# n_tree:  17 , cross-validation. Current accuracies: [0.77, 0.83, 0.81, 0.74, 0.65, 0.74, 0.8166666666666667, 0.7733333333333333]
# iter:  1
# n_tree:  17 , cross-validation. Current accuracies: [0.77, 0.83, 0.81, 0.74, 0.65, 0.74, 0.8166666666666667, 0.7733333333333333, 0.83]
# iter:  1
# n_tree:  17 , cross-validation. Current accuracies: [0.77, 0.83, 0.81, 0.74, 0.65, 0.74, 0.8166666666666667, 0.7733333333333333, 0.83, 0.69]
# When n_tree is  17 , the accuracy is  0.765
# iter:  1
# n_tree:  18 , cross-validation. Current accuracies: [0.78]
# iter:  1
# n_tree:  18 , cross-validation. Current accuracies: [0.78, 0.8433333333333334]
# iter:  1
# n_tree:  18 , cross-validation. Current accuracies: [0.78, 0.8433333333333334, 0.8666666666666667]
# iter:  1
# n_tree:  18 , cross-validation. Current accuracies: [0.78, 0.8433333333333334, 0.8666666666666667, 0.7733333333333333]
# iter:  1
# n_tree:  18 , cross-validation. Current accuracies: [0.78, 0.8433333333333334, 0.8666666666666667, 0.7733333333333333, 0.6033333333333334]
# iter:  1
# n_tree:  18 , cross-validation. Current accuracies: [0.78, 0.8433333333333334, 0.8666666666666667, 0.7733333333333333, 0.6033333333333334, 0.7633333333333333]
# iter:  1
# n_tree:  18 , cross-validation. Current accuracies: [0.78, 0.8433333333333334, 0.8666666666666667, 0.7733333333333333, 0.6033333333333334, 0.7633333333333333, 0.83]
# iter:  1
# n_tree:  18 , cross-validation. Current accuracies: [0.78, 0.8433333333333334, 0.8666666666666667, 0.7733333333333333, 0.6033333333333334, 0.7633333333333333, 0.83, 0.7966666666666666]
# iter:  1
# n_tree:  18 , cross-validation. Current accuracies: [0.78, 0.8433333333333334, 0.8666666666666667, 0.7733333333333333, 0.6033333333333334, 0.7633333333333333, 0.83, 0.7966666666666666, 0.7666666666666667]
# iter:  1
# n_tree:  18 , cross-validation. Current accuracies: [0.78, 0.8433333333333334, 0.8666666666666667, 0.7733333333333333, 0.6033333333333334, 0.7633333333333333, 0.83, 0.7966666666666666, 0.7666666666666667, 0.7633333333333333]
# When n_tree is  18 , the accuracy is  0.7786666666666667
# iter:  1
# n_tree:  19 , cross-validation. Current accuracies: [0.7433333333333333]
# iter:  1
# n_tree:  19 , cross-validation. Current accuracies: [0.7433333333333333, 0.87]
# iter:  1
# n_tree:  19 , cross-validation. Current accuracies: [0.7433333333333333, 0.87, 0.8933333333333333]
# iter:  1
# n_tree:  19 , cross-validation. Current accuracies: [0.7433333333333333, 0.87, 0.8933333333333333, 0.7666666666666667]
# iter:  1
# n_tree:  19 , cross-validation. Current accuracies: [0.7433333333333333, 0.87, 0.8933333333333333, 0.7666666666666667, 0.6266666666666667]
# iter:  1
# n_tree:  19 , cross-validation. Current accuracies: [0.7433333333333333, 0.87, 0.8933333333333333, 0.7666666666666667, 0.6266666666666667, 0.8266666666666667]
# iter:  1
# n_tree:  19 , cross-validation. Current accuracies: [0.7433333333333333, 0.87, 0.8933333333333333, 0.7666666666666667, 0.6266666666666667, 0.8266666666666667, 0.8533333333333334]
# iter:  1
# n_tree:  19 , cross-validation. Current accuracies: [0.7433333333333333, 0.87, 0.8933333333333333, 0.7666666666666667, 0.6266666666666667, 0.8266666666666667, 0.8533333333333334, 0.7466666666666667]
# iter:  1
# n_tree:  19 , cross-validation. Current accuracies: [0.7433333333333333, 0.87, 0.8933333333333333, 0.7666666666666667, 0.6266666666666667, 0.8266666666666667, 0.8533333333333334, 0.7466666666666667, 0.79]
# iter:  1
# n_tree:  19 , cross-validation. Current accuracies: [0.7433333333333333, 0.87, 0.8933333333333333, 0.7666666666666667, 0.6266666666666667, 0.8266666666666667, 0.8533333333333334, 0.7466666666666667, 0.79, 0.7033333333333334]
# When n_tree is  19 , the accuracy is  0.782
# iter:  1
# n_tree:  20 , cross-validation. Current accuracies: [0.7866666666666666]
# iter:  1
# n_tree:  20 , cross-validation. Current accuracies: [0.7866666666666666, 0.8566666666666667]
# iter:  1
# n_tree:  20 , cross-validation. Current accuracies: [0.7866666666666666, 0.8566666666666667, 0.83]
# iter:  1
# ...
# When n_tree is  20 , the accuracy is  0.7809999999999999
# iter:  1
# n_tree:  21 , cross-validation. Current accuracies: [0.7866666666666666]
# iter:  1
# n_tree:  21 , cross-validation. Current accuracies: [0.7866666666666666, 0.8633333333333333]
# iter:  1
# n_tree:  21 , cross-validation. Current accuracies: [0.7866666666666666, 0.8633333333333333, 0.88]
# iter:  1
# n_tree:  21 , cross-validation. Current accuracies: [0.7866666666666666, 0.8633333333333333, 0.88, 0.79]
# iter:  1
# n_tree:  21 , cross-validation. Current accuracies: [0.7866666666666666, 0.8633333333333333, 0.88, 0.79, 0.6433333333333333]
# iter:  1
# n_tree:  21 , cross-validation. Current accuracies: [0.7866666666666666, 0.8633333333333333, 0.88, 0.79, 0.6433333333333333, 0.7566666666666667]
# iter:  1
# n_tree:  21 , cross-validation. Current accuracies: [0.7866666666666666, 0.8633333333333333, 0.88, 0.79, 0.6433333333333333, 0.7566666666666667, 0.8366666666666667]
# iter:  1
# n_tree:  21 , cross-validation. Current accuracies: [0.7866666666666666, 0.8633333333333333, 0.88, 0.79, 0.6433333333333333, 0.7566666666666667, 0.8366666666666667, 0.8133333333333334]
# iter:  1
# n_tree:  21 , cross-validation. Current accuracies: [0.7866666666666666, 0.8633333333333333, 0.88, 0.79, 0.6433333333333333, 0.7566666666666667, 0.8366666666666667, 0.8133333333333334, 0.8533333333333334]
# iter:  1
# n_tree:  21 , cross-validation. Current accuracies: [0.7866666666666666, 0.8633333333333333, 0.88, 0.79, 0.6433333333333333, 0.7566666666666667, 0.8366666666666667, 0.8133333333333334, 0.8533333333333334, 0.7233333333333334]
# When n_tree is  21 , the accuracy is  0.7946666666666666
# iter:  1
# n_tree:  22 , cross-validation. Current accuracies: [0.7533333333333333]
# iter:  1
# n_tree:  22 , cross-validation. Current accuracies: [0.7533333333333333, 0.8533333333333334]
# iter:  1
# n_tree:  22 , cross-validation. Current accuracies: [0.7533333333333333, 0.8533333333333334, 0.86]
# iter:  1
# n_tree:  22 , cross-validation. Current accuracies: [0.7533333333333333, 0.8533333333333334, 0.86, 0.81]
# iter:  1
# n_tree:  22 , cross-validation. Current accuracies: [0.7533333333333333, 0.8533333333333334, 0.86, 0.81, 0.6366666666666667]
# iter:  1
# n_tree:  22 , cross-validation. Current accuracies: [0.7533333333333333, 0.8533333333333334, 0.86, 0.81, 0.6366666666666667, 0.7533333333333333]
# iter:  1
# n_tree:  22 , cross-validation. Current accuracies: [0.7533333333333333, 0.8533333333333334, 0.86, 0.81, 0.6366666666666667, 0.7533333333333333, 0.8433333333333334]
# iter:  1
# n_tree:  22 , cross-validation. Current accuracies: [0.7533333333333333, 0.8533333333333334, 0.86, 0.81, 0.6366666666666667, 0.7533333333333333, 0.8433333333333334, 0.8433333333333334]
# iter:  1
# n_tree:  22 , cross-validation. Current accuracies: [0.7533333333333333, 0.8533333333333334, 0.86, 0.81, 0.6366666666666667, 0.7533333333333333, 0.8433333333333334, 0.8433333333333334, 0.8566666666666667]
# iter:  1
# n_tree:  22 , cross-validation. Current accuracies: [0.7533333333333333, 0.8533333333333334, 0.86, 0.81, 0.6366666666666667, 0.7533333333333333, 0.8433333333333334, 0.8433333333333334, 0.8566666666666667, 0.8033333333333333]
# When n_tree is  22 , the accuracy is  0.8013333333333333
# iter:  1
# n_tree:  23 , cross-validation. Current accuracies: [0.7466666666666667]
# iter:  1
# n_tree:  23 , cross-validation. Current accuracies: [0.7466666666666667, 0.8433333333333334]
# iter:  1
# n_tree:  23 , cross-validation. Current accuracies: [0.7466666666666667, 0.8433333333333334, 0.8233333333333334]
# iter:  1
# n_tree:  23 , cross-validation. Current accuracies: [0.7466666666666667, 0.8433333333333334, 0.8233333333333334, 0.7833333333333333]
# iter:  1
# n_tree:  23 , cross-validation. Current accuracies: [0.7466666666666667, 0.8433333333333334, 0.8233333333333334, 0.7833333333333333, 0.6466666666666666]
# iter:  1
# n_tree:  23 , cross-validation. Current accuracies: [0.7466666666666667, 0.8433333333333334, 0.8233333333333334, 0.7833333333333333, 0.6466666666666666, 0.7766666666666666]
# iter:  1
# n_tree:  23 , cross-validation. Current accuracies: [0.7466666666666667, 0.8433333333333334, 0.8233333333333334, 0.7833333333333333, 0.6466666666666666, 0.7766666666666666, 0.8266666666666667]
# iter:  1
# n_tree:  23 , cross-validation. Current accuracies: [0.7466666666666667, 0.8433333333333334, 0.8233333333333334, 0.7833333333333333, 0.6466666666666666, 0.7766666666666666, 0.8266666666666667, 0.8333333333333334]
# iter:  1
# n_tree:  23 , cross-validation. Current accuracies: [0.7466666666666667, 0.8433333333333334, 0.8233333333333334, 0.7833333333333333, 0.6466666666666666, 0.7766666666666666, 0.8266666666666667, 0.8333333333333334, 0.85]
# iter:  1
# n_tree:  23 , cross-validation. Current accuracies: [0.7466666666666667, 0.8433333333333334, 0.8233333333333334, 0.7833333333333333, 0.6466666666666666, 0.7766666666666666, 0.8266666666666667, 0.8333333333333334, 0.85, 0.74]
# When n_tree is  23 , the accuracy is  0.787
# iter:  1
# n_tree:  24 , cross-validation. Current accuracies: [0.73]
# iter:  1
# n_tree:  24 , cross-validation. Current accuracies: [0.73, 0.9066666666666666]
# iter:  1
# n_tree:  24 , cross-validation. Current accuracies: [0.73, 0.9066666666666666, 0.83]
# iter:  1
# n_tree:  24 , cross-validation. Current accuracies: [0.73, 0.9066666666666666, 0.83, 0.7833333333333333]
# iter:  1
# n_tree:  24 , cross-validation. Current accuracies: [0.73, 0.9066666666666666, 0.83, 0.7833333333333333, 0.6433333333333333]
# iter:  1
# n_tree:  24 , cross-validation. Current accuracies: [0.73, 0.9066666666666666, 0.83, 0.7833333333333333, 0.6433333333333333, 0.79]
# iter:  1
# n_tree:  24 , cross-validation. Current accuracies: [0.73, 0.9066666666666666, 0.83, 0.7833333333333333, 0.6433333333333333, 0.79, 0.8833333333333333]
# iter:  1
# n_tree:  24 , cross-validation. Current accuracies: [0.73, 0.9066666666666666, 0.83, 0.7833333333333333, 0.6433333333333333, 0.79, 0.8833333333333333, 0.83]
# iter:  1
# n_tree:  24 , cross-validation. Current accuracies: [0.73, 0.9066666666666666, 0.83, 0.7833333333333333, 0.6433333333333333, 0.79, 0.8833333333333333, 0.83, 0.84]
# iter:  1
# n_tree:  24 , cross-validation. Current accuracies: [0.73, 0.9066666666666666, 0.83, 0.7833333333333333, 0.6433333333333333, 0.79, 0.8833333333333333, 0.83, 0.84, 0.8166666666666667]
# When n_tree is  24 , the accuracy is  0.8053333333333332
# iter:  1
# n_tree:  25 , cross-validation. Current accuracies: [0.7666666666666667]
# iter:  1
# n_tree:  25 , cross-validation. Current accuracies: [0.7666666666666667, 0.8666666666666667]
# iter:  1
# n_tree:  25 , cross-validation. Current accuracies: [0.7666666666666667, 0.8666666666666667, 0.8]
# iter:  1
# n_tree:  25 , cross-validation. Current accuracies: [0.7666666666666667, 0.8666666666666667, 0.8, 0.7533333333333333]
# iter:  1
# n_tree:  25 , cross-validation. Current accuracies: [0.7666666666666667, 0.8666666666666667, 0.8, 0.7533333333333333, 0.67]
# iter:  1
# n_tree:  25 , cross-validation. Current accuracies: [0.7666666666666667, 0.8666666666666667, 0.8, 0.7533333333333333, 0.67, 0.75]
# iter:  1
# n_tree:  25 , cross-validation. Current accuracies: [0.7666666666666667, 0.8666666666666667, 0.8, 0.7533333333333333, 0.67, 0.75, 0.8433333333333334]
# iter:  1
# n_tree:  25 , cross-validation. Current accuracies: [0.7666666666666667, 0.8666666666666667, 0.8, 0.7533333333333333, 0.67, 0.75, 0.8433333333333334, 0.7733333333333333]
# iter:  1
# n_tree:  25 , cross-validation. Current accuracies: [0.7666666666666667, 0.8666666666666667, 0.8, 0.7533333333333333, 0.67, 0.75, 0.8433333333333334, 0.7733333333333333, 0.8166666666666667]
# iter:  1
# n_tree:  25 , cross-validation. Current accuracies: [0.7666666666666667, 0.8666666666666667, 0.8, 0.7533333333333333, 0.67, 0.75, 0.8433333333333334, 0.7733333333333333, 0.8166666666666667, 0.7133333333333334]
# When n_tree is  25 , the accuracy is  0.7753333333333332
# iter:  1
# n_tree:  26 , cross-validation. Current accuracies: [0.8]
# iter:  1
# n_tree:  26 , cross-validation. Current accuracies: [0.8, 0.8933333333333333]
# iter:  1
# n_tree:  26 , cross-validation. Current accuracies: [0.8, 0.8933333333333333, 0.8666666666666667]
# iter:  1
# n_tree:  26 , cross-validation. Current accuracies: [0.8, 0.8933333333333333, 0.8666666666666667, 0.7733333333333333]
# iter:  1
# n_tree:  26 , cross-validation. Current accuracies: [0.8, 0.8933333333333333, 0.8666666666666667, 0.7733333333333333, 0.73]
# iter:  1
# n_tree:  26 , cross-validation. Current accuracies: [0.8, 0.8933333333333333, 0.8666666666666667, 0.7733333333333333, 0.73, 0.7633333333333333]
# iter:  1
# n_tree:  26 , cross-validation. Current accuracies: [0.8, 0.8933333333333333, 0.8666666666666667, 0.7733333333333333, 0.73, 0.7633333333333333, 0.8066666666666666]
# iter:  1
# n_tree:  26 , cross-validation. Current accuracies: [0.8, 0.8933333333333333, 0.8666666666666667, 0.7733333333333333, 0.73, 0.7633333333333333, 0.8066666666666666, 0.7733333333333333]
# iter:  1
# n_tree:  26 , cross-validation. Current accuracies: [0.8, 0.8933333333333333, 0.8666666666666667, 0.7733333333333333, 0.73, 0.7633333333333333, 0.8066666666666666, 0.7733333333333333, 0.84]
# iter:  1
# n_tree:  26 , cross-validation. Current accuracies: [0.8, 0.8933333333333333, 0.8666666666666667, 0.7733333333333333, 0.73, 0.7633333333333333, 0.8066666666666666, 0.7733333333333333, 0.84, 0.77]
# When n_tree is  26 , the accuracy is  0.8016666666666665
# iter:  1
# n_tree:  27 , cross-validation. Current accuracies: [0.7766666666666666]
# iter:  1
# n_tree:  27 , cross-validation. Current accuracies: [0.7766666666666666, 0.8833333333333333]
# iter:  1
# n_tree:  27 , cross-validation. Current accuracies: [0.7766666666666666, 0.8833333333333333, 0.8866666666666667]
# iter:  1
# n_tree:  27 , cross-validation. Current accuracies: [0.7766666666666666, 0.8833333333333333, 0.8866666666666667, 0.8233333333333334]
# iter:  1
# n_tree:  27 , cross-validation. Current accuracies: [0.7766666666666666, 0.8833333333333333, 0.8866666666666667, 0.8233333333333334, 0.61]
# iter:  1
# n_tree:  27 , cross-validation. Current accuracies: [0.7766666666666666, 0.8833333333333333, 0.8866666666666667, 0.8233333333333334, 0.61, 0.8166666666666667]
# iter:  1
# n_tree:  27 , cross-validation. Current accuracies: [0.7766666666666666, 0.8833333333333333, 0.8866666666666667, 0.8233333333333334, 0.61, 0.8166666666666667, 0.8533333333333334]
# iter:  1
# n_tree:  27 , cross-validation. Current accuracies: [0.7766666666666666, 0.8833333333333333, 0.8866666666666667, 0.8233333333333334, 0.61, 0.8166666666666667, 0.8533333333333334, 0.74]
# iter:  1
# n_tree:  27 , cross-validation. Current accuracies: [0.7766666666666666, 0.8833333333333333, 0.8866666666666667, 0.8233333333333334, 0.61, 0.8166666666666667, 0.8533333333333334, 0.74, 0.87]
# iter:  1
# n_tree:  27 , cross-validation. Current accuracies: [0.7766666666666666, 0.8833333333333333, 0.8866666666666667, 0.8233333333333334, 0.61, 0.8166666666666667, 0.8533333333333334, 0.74, 0.87, 0.8033333333333333]
# When n_tree is  27 , the accuracy is  0.8063333333333335
# iter:  1
# n_tree:  28 , cross-validation. Current accuracies: [0.7633333333333333]
# iter:  1
# n_tree:  28 , cross-validation. Current accuracies: [0.7633333333333333, 0.8566666666666667]
# iter:  1
# n_tree:  28 , cross-validation. Current accuracies: [0.7633333333333333, 0.8566666666666667, 0.8533333333333334]
# iter:  1
# n_tree:  28 , cross-validation. Current accuracies: [0.7633333333333333, 0.8566666666666667, 0.8533333333333334, 0.7933333333333333]
# iter:  1
# n_tree:  28 , cross-validation. Current accuracies: [0.7633333333333333, 0.8566666666666667, 0.8533333333333334, 0.7933333333333333, 0.6366666666666667]
# iter:  1
# n_tree:  28 , cross-validation. Current accuracies: [0.7633333333333333, 0.8566666666666667, 0.8533333333333334, 0.7933333333333333, 0.6366666666666667, 0.75]
# iter:  1
# n_tree:  28 , cross-validation. Current accuracies: [0.7633333333333333, 0.8566666666666667, 0.8533333333333334, 0.7933333333333333, 0.6366666666666667, 0.75, 0.8366666666666667]
# iter:  1
# n_tree:  28 , cross-validation. Current accuracies: [0.7633333333333333, 0.8566666666666667, 0.8533333333333334, 0.7933333333333333, 0.6366666666666667, 0.75, 0.8366666666666667, 0.7733333333333333]
# iter:  1
# n_tree:  28 , cross-validation. Current accuracies: [0.7633333333333333, 0.8566666666666667, 0.8533333333333334, 0.7933333333333333, 0.6366666666666667, 0.75, 0.8366666666666667, 0.7733333333333333, 0.8433333333333334]
# iter:  1
# n_tree:  28 , cross-validation. Current accuracies: [0.7633333333333333, 0.8566666666666667, 0.8533333333333334, 0.7933333333333333, 0.6366666666666667, 0.75, 0.8366666666666667, 0.7733333333333333, 0.8433333333333334, 0.7466666666666667]
# When n_tree is  28 , the accuracy is  0.7853333333333334
# iter:  1
# n_tree:  29 , cross-validation. Current accuracies: [0.7333333333333333]
# iter:  1
# n_tree:  29 , cross-validation. Current accuracies: [0.7333333333333333, 0.8833333333333333]
# iter:  1
# n_tree:  29 , cross-validation. Current accuracies: [0.7333333333333333, 0.8833333333333333, 0.7466666666666667]
# iter:  1
# n_tree:  29 , cross-validation. Current accuracies: [0.7333333333333333, 0.8833333333333333, 0.7466666666666667, 0.8066666666666666]
# iter:  1
# n_tree:  29 , cross-validation. Current accuracies: [0.7333333333333333, 0.8833333333333333, 0.7466666666666667, 0.8066666666666666, 0.66]
# iter:  1
# n_tree:  29 , cross-validation. Current accuracies: [0.7333333333333333, 0.8833333333333333, 0.7466666666666667, 0.8066666666666666, 0.66, 0.7333333333333333]
# iter:  1
# n_tree:  29 , cross-validation. Current accuracies: [0.7333333333333333, 0.8833333333333333, 0.7466666666666667, 0.8066666666666666, 0.66, 0.7333333333333333, 0.8833333333333333]
# iter:  1
# n_tree:  29 , cross-validation. Current accuracies: [0.7333333333333333, 0.8833333333333333, 0.7466666666666667, 0.8066666666666666, 0.66, 0.7333333333333333, 0.8833333333333333, 0.8166666666666667]
# iter:  1
# n_tree:  29 , cross-validation. Current accuracies: [0.7333333333333333, 0.8833333333333333, 0.7466666666666667, 0.8066666666666666, 0.66, 0.7333333333333333, 0.8833333333333333, 0.8166666666666667, 0.8266666666666667]
# iter:  1
# n_tree:  29 , cross-validation. Current accuracies: [0.7333333333333333, 0.8833333333333333, 0.7466666666666667, 0.8066666666666666, 0.66, 0.7333333333333333, 0.8833333333333333, 0.8166666666666667, 0.8266666666666667, 0.7633333333333333]
# When n_tree is  29 , the accuracy is  0.7853333333333333
# iter:  1
# n_tree:  30 , cross-validation. Current accuracies: [0.8133333333333334]
# iter:  1
# n_tree:  30 , cross-validation. Current accuracies: [0.8133333333333334, 0.8833333333333333]
# iter:  1
# n_tree:  30 , cross-validation. Current accuracies: [0.8133333333333334, 0.8833333333333333, 0.8833333333333333]
# iter:  1
# n_tree:  30 , cross-validation. Current accuracies: [0.8133333333333334, 0.8833333333333333, 0.8833333333333333, 0.81]
# iter:  1
# n_tree:  30 , cross-validation. Current accuracies: [0.8133333333333334, 0.8833333333333333, 0.8833333333333333, 0.81, 0.64]
# iter:  1
# n_tree:  30 , cross-validation. Current accuracies: [0.8133333333333334, 0.8833333333333333, 0.8833333333333333, 0.81, 0.64, 0.7633333333333333]
# iter:  1
# n_tree:  30 , cross-validation. Current accuracies: [0.8133333333333334, 0.8833333333333333, 0.8833333333333333, 0.81, 0.64, 0.7633333333333333, 0.82]
# iter:  1
# n_tree:  30 , cross-validation. Current accuracies: [0.8133333333333334, 0.8833333333333333, 0.8833333333333333, 0.81, 0.64, 0.7633333333333333, 0.82, 0.8433333333333334]
# iter:  1
# n_tree:  30 , cross-validation. Current accuracies: [0.8133333333333334, 0.8833333333333333, 0.8833333333333333, 0.81, 0.64, 0.7633333333333333, 0.82, 0.8433333333333334, 0.8233333333333334]
# iter:  1
# n_tree:  30 , cross-validation. Current accuracies: [0.8133333333333334, 0.8833333333333333, 0.8833333333333333, 0.81, 0.64, 0.7633333333333333, 0.82, 0.8433333333333334, 0.8233333333333334, 0.69]
# When n_tree is  30 , the accuracy is  0.797

# %%
# Accuracy-ntree plot

t = np.array(num_trees).reshape((2,-1))
t = np.average(t,axis =0)
a = np.array(acc).reshape((2,-1))
a = np.average(a,axis =0)

plt.figure()
plt.subplot()
plt.plot(t,a)
plt.xlabel('number of trees')
plt.ylabel('Accuracy (Average of 2 iterations)')
plt.title('Hyperparameters Tuning: number of trees')
plt.xticks(range(10,31,2))
# Out:
# ([<matplotlib.axis.XTick at 0x16d1c9de850>,
#   <matplotlib.axis.XTick at 0x16d1c9de820>,
#   <matplotlib.axis.XTick at 0x16d1c9d83a0>,
#   <matplotlib.axis.XTick at 0x16d1ca064f0>,
#   <matplotlib.axis.XTick at 0x16d1ca06130>,
#   <matplotlib.axis.XTick at 0x16d1ca06d60>,
#   <matplotlib.axis.XTick at 0x16d1ca0d2b0>,
#   <matplotlib.axis.XTick at 0x16d1ca0d7c0>,
#   <matplotlib.axis.XTick at 0x16d1ca0dcd0>,
#   <matplotlib.axis.XTick at 0x16d1ca12220>,
#   <matplotlib.axis.XTick at 0x16d1ca12730>],
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
# sklearn Random Forest
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

acc_RandomForest = []
for i in range(50):
    X_train, X_test, y_train, y_test = train_test_split(X_all, Y_all, test_size=0.25)
    clf = RandomForestClassifier(n_estimators=40, max_depth=30)
    clf = clf.fit(X_train, y_train)
    Y_predict = clf.predict(X_test)
    accuracy=accuracy_score(Y_predict,y_test)
    #print('Accuracy_RandomForest: ',accuracy)
    acc_RandomForest.append(accuracy)

# %%
np.mean(acc_RandomForest)
# Out:
# 0.9253866666666667

# %%
acc_proglean = []
for i in range(50):
    X_train, X_test, Y_train, Y_test = train_test_split(X_all, Y_all, test_size=0.25)
    progressive_learner = ProgressiveLearner(
        default_transformer_class=default_transformer_class,
        default_transformer_kwargs=default_transformer_kwargs,
        default_voter_class=default_voter_class,
        default_voter_kwargs=default_voter_kwargs,
        default_decider_class=default_decider_class,
    )
    progressive_learner.add_task(
        X=X_train,
        y=Y_train,
        task_id=0,
        num_transformers=19,
        transformer_voter_decider_split=[0.67, 0.33, 0],
        decider_kwargs={"classes": np.unique(y_train)},
    )
    task_0_predictions = progressive_learner.predict(X_test, task_id=0)
    acc_proglean.append(np.mean(task_0_predictions == Y_test))
    #print(acc_proglean)

# %%
np.mean(acc_proglean)
# Out:
# 0.84792

# %%
d = {'RandomForest': np.array(acc_RandomForest),
     'ProgLearn_L2F': np.array(acc_proglean)}
df = pd.DataFrame(data=d)
#boxplot = df.boxplot()
boxplot = df.boxplot(column=['RandomForest', 'ProgLearn_L2F'])
#plt.xlabel('Algorithm')
plt.ylabel('Average of Accuracy (50 run-times)')
plt.title('Comparison between L2F and RandomForest')
# Out:
# Text(0.5, 1.0, 'Comparison between L2F and RandomForest')

# %%
Y.shape
# Out:
# (500,)

# %%
############################
num_iteration = 1
ntrees = 19


model = 'dnn' # uf or dnn
speakers = Label_speaker.copy()
    
iteration = []
accuracies_across_tasks = []

############################

if model == "dnn":
    import keras
    from keras import layers
    default_transformer_class = NeuralClassificationTransformer

    network = keras.Sequential()
    network.add(
        layers.Conv2D(
            filters=16,
            kernel_size=(3, 3),
            activation="relu",
            input_shape=np.shape(train_x_task0)[1:],
        )
    )
    network.add(
        layers.Conv2D(
            filters=32,
            kernel_size=(3, 3),
            strides=2,
            padding="same",
            activation="relu",
        )
    )
    network.add(
        layers.Conv2D(
            filters=64,
            kernel_size=(3, 3),
            strides=2,
            padding="same",
            activation="relu",
        )
    )
    network.add(
        layers.Conv2D(
            filters=128,
            kernel_size=(3, 3),
            strides=2,
            padding="same",
            activation="relu",
        )
    )
    network.add(
        layers.Conv2D(
            filters=254,
            kernel_size=(3, 3),
            strides=2,
            padding="same",
            activation="relu",
        )
    )

    network.add(layers.Flatten())
    network.add(layers.Dense(2000, activation="relu"))
    network.add(layers.Dense(2000, activation="relu"))
    network.add(layers.Dense(units=10, activation="softmax"))

    default_transformer_kwargs = {
        "network": network,
        "euclidean_layer_idx": -2,
        "num_classes": 10,
        "optimizer": keras.optimizers.Adam(3e-4),
    }

    default_voter_class = KNNClassificationVoter
    default_voter_kwargs = {"k": int(np.log2(num_points_per_task * 0.33))}

    default_decider_class = SimpleArgmaxAverage
elif model == "uf":
    default_transformer_class = TreeClassificationTransformer
    default_transformer_kwargs = {"kwargs": {"max_depth": 30}}

    default_voter_class = TreeClassificationVoter
    default_voter_kwargs = {}

    default_decider_class = SimpleArgmaxAverage
    
    

######
for i in range(num_iteration):
    print('Iteration ',i)
    np.random.shuffle(speakers)
    for j , speaker in enumerate(speakers):
        index = np.where(Y_all_speaker==speaker)
        X = X_all[index]
        Y = Y_all[index]

        if j == 0:
            progressive_learner = ProgressiveLearner(
                default_transformer_class=default_transformer_class,
                default_transformer_kwargs=default_transformer_kwargs,
                default_voter_class=default_voter_class,
                default_voter_kwargs=default_voter_kwargs,
                default_decider_class=default_decider_class,
            )

            train_x_task0, test_x_task0, train_y_task0, test_y_task0 = train_test_split(X, Y, test_size=0.25)
            progressive_learner.add_task(
                X=train_x_task0,
                y=train_y_task0,
                task_id = 0,
                num_transformers= 1 if model == "dnn" else ntrees,
                transformer_voter_decider_split=[0.67, 0.33, 0],
                decider_kwargs={"classes": np.unique(train_y_task0)},
            )
            task_0_predictions = progressive_learner.predict(test_x_task0, task_id=0)
            iteration.append(i)
            accuracies_across_tasks.append(np.mean(task_0_predictions == test_y_task0))
            print('Task finished, accuracy: ',accuracies_across_tasks)
        else:
            progressive_learner.add_transformer(
                X=X,
                y=Y,
                transformer_data_proportion=1,
                num_transformers=1 if model == "dnn" else ntrees,
                backward_task_ids=[0],
            )
            task_0_predictions = progressive_learner.predict(test_x_task0, task_id=0)
            iteration.append(i)
            accuracies_across_tasks.append(np.mean(task_0_predictions == test_y_task0))
            print('Task finished, accuracy: ',accuracies_across_tasks)

print('All done!')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-484aa07c6fe2> in <module>
#      18
#      19     network = keras.Sequential()
# ---> 20     network.add(
#      21         layers.Conv2D(
#      22             filters=16,
#
# D:\Python Exploration\VirEnv\progressivelearning\lib\site-packages\tensorflow\python\training\tracking\base.py in _method_wrapper(self, *args, **kwargs)
#     455     self._self_setattr_tracking = False  # pylint: disable=protected-access
#     456     try:
# --> 457       result = method(self, *args, **kwargs)
#     458     finally:
#     459       self._self_setattr_tracking = previous_value  # pylint: disable=protected-access
#
# D:\Python Exploration\VirEnv\progressivelearning\lib\site-packages\tensorflow\python\keras\engine\sequential.py in add(self, layer)
#     204           # and create the node connecting the current layer
#     205           # to the input layer we just created.
# --> 206           layer(x)
#     207           set_inputs = True
#     208
#
# D:\Python Exploration\VirEnv\progressivelearning\lib\site-packages\tensorflow\python\keras\engine\base_layer.py in __call__(self, *args, **kwargs)
#     923     # >> model = tf.keras.Model(inputs, outputs)
#     924     if _in_functional_construction_mode(self, inputs, args, kwargs, input_list):
# --> 925       return self._functional_construction_call(inputs, args, kwargs,
#     926                                                 input_list)
#     927
#
# D:\Python Exploration\VirEnv\progressivelearning\lib\site-packages\tensorflow\python\keras\engine\base_layer.py in _functional_construction_call(self, inputs, args, kwargs, input_list)
#    1090       # TODO(reedwm): We should assert input compatibility after the inputs
#    1091       # are casted, not before.
# -> 1092       input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#    1093       graph = backend.get_graph()
#    1094       # Use `self._name_scope()` to avoid auto-incrementing the name.
#
# D:\Python Exploration\VirEnv\progressivelearning\lib\site-packages\tensorflow\python\keras\engine\input_spec.py in assert_input_compatibility(input_spec, inputs, layer_name)
#     189       ndim = x.shape.ndims
#     190       if ndim is not None and ndim < spec.min_ndim:
# --> 191         raise ValueError('Input ' + str(input_index) + ' of layer ' +
#     192                          layer_name + ' is incompatible with the layer: '
#     193                          ': expected min_ndim=' + str(spec.min_ndim) +
#
# ValueError: Input 0 of layer conv2d_1 is incompatible with the layer: : expected min_ndim=4, found ndim=2. Full shape received: [None, 784]

# %%
aver_accuracy = np.array(accuracies_across_tasks).reshape((num_iteration,6))
aver_accuracy = np.average(aver_accuracy,axis =0)

# %%
plt.figure()
plt.subplot()
plt.plot(range(1,7),aver_accuracy)
plt.xlabel('Number of tasks seen')
plt.ylabel('Accuracy (Task 1)')
plt.title('L2F: Average of Accuracy for 100 iterations')
#plt.xticks(range(10,31,2))
# Out:
# Text(0.5, 1.0, 'L2F: Average of Accuracy for 100 iterations')

# %%
err = 1- aver_accuracy
bte = err[0]/err

plt.figure()
plt.subplot()
plt.plot(range(1,7),bte)
plt.xlabel('Number of tasks seen')
plt.ylabel('BTE (Task 1)')
plt.title('L2F: Backward Transfer Efficiency (100 iterations)')
# Out:
# Text(0.5, 1.0, 'L2F: Backward Transfer Efficiency (100 iterations)')
