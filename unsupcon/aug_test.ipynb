# %%
import matplotlib.pyplot as plt
import numpy as np
import tensorflow.keras as keras

from unsupcon_loss import unsupervised_contrastive_loss

# %%
(X_train, y_train), (X_test, y_test) = keras.datasets.cifar100.load_data()
X = np.concatenate([X_train, X_test])
print(np.shape(X))
X_batch = X[:10, :, :, :]
for i in range(np.size(X_batch, 0)):
    plt.figure()
    plt.imshow(X_batch[i])
# Out:
# (60000, 32, 32, 3)

# %%
X_batch_aug = unsupervised_contrastive_loss(X_batch)
# Out:
# 2021-11-17 13:01:28.804815: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-17 13:01:28.844408: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-17 13:01:28.844741: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-17 13:01:28.845594: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# ...

# %%
print(np.shape(X_batch_aug))
for i in range(np.size(X_batch_aug, 0)):
    plt.figure()
    plt.imshow(X_batch_aug[i])
# Out:
# (10, 32, 32, 1)
